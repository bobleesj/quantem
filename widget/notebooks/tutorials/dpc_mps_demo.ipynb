# %% [markdown]
# # DPC / iCoM on MacBook (MPS) - no binning
#
# CoM, DPC, iDPC on the **full no-bin** 4D-STEM stack, on Apple Metal. Bit-exact vs CUDA.

# %% [markdown]
# ## Environment

# %%
from quantem.widget import load, dpc, Show2D, device_info
device_info()                       # version, date, GPU / MacBook chip

# %% [markdown]
# ## Load (no bin) + compute DPC

# %%
result = dpc(load("/Users/macbook/data/samsung/logic_013_master.h5"), verbose=True)   # load + Metal CoM + rotation + iDPC

# %% [markdown]
# ## iDPC phase  (projected potential / atoms)

# %%
Show2D(result.phase)

# %% [markdown]
# ## CoM field  (DPC gradient: x, y deflection)

# %%
Show2D(result.com_col)

# %%
Show2D(result.com_row)
