# %% [markdown]
# # DPC / iCoM on MacBook (MPS) - no binning
#
# CoM, DPC, and iDPC on the **full no-bin** 4D-STEM stack, computed on Apple Metal.
# Bit-exact vs quantem.live's CUDA path.

# %% [markdown]
# ## Load + compute

# %%
from quantem.widget import load, dpc, Show2D

result = dpc(load("/Users/macbook/data/samsung/logic_013_master.h5", verbose=False))

# %% [markdown]
# ## iDPC phase  (projected potential / atoms)

# %%
Show2D(result.phase)

# %% [markdown]
# ## CoM field  (DPC gradient: x, y deflection)

# %%
Show2D(result.com_col)

# %%
Show2D(result.com_row)
